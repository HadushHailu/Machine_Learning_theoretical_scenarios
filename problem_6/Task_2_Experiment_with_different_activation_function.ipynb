# %% [markdown]
# # Experiment with Different Activation Functions

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, optimizers
import matplotlib.pyplot as plt

# Load and preprocess CIFAR10 dataset
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_images, test_images = train_images / 255.0, test_images / 255.0

# Define activation functions to compare
activation_functions = ['relu', 'sigmoid', 'tanh']

# %%
for activation_function in activation_functions:
    print(f"Training model with activation function: {activation_function}")
    # Define the CNN model with specified activation function
    model = models.Sequential()
    model.add(layers.Conv2D(32, (3, 3), activation=activation_function, input_shape=(32, 32, 3)))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation=activation_function))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation=activation_function))
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation=activation_function))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(10, activation='softmax'))

    # Compile the model
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    # Train the model
    history = model.fit(train_images, train_labels, epochs=10, 
                        validation_data=(test_images, test_labels))

    # Evaluate the model
    test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
    print(f"Test accuracy with {activation_function} activation function: {test_acc}\n")

    # Plot training history
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.ylim([0, 1])
    plt.title(f"Activation Function: {activation_function}")
    plt.legend(loc='lower right')
    plt.show()
# Out:
# Training model with activation function: relu
# 2024-05-07 13:36:15.192247: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-05-07 13:36:15.192733: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (hadush-GF63-Thin-10SCSR): /proc/driver/nvidia/version does not exist
# 2024-05-07 13:36:15.194481: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-07 13:36:16.030518: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 614400000 exceeds 10% of free system memory.
# Epoch 1/10
# 1560/1563 [============================>.] - ETA: 0s - loss: 1.6872 - accuracy: 0.3761
# 2024-05-07 13:36:35.494579: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 122880000 exceeds 10% of free system memory.
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.6868 - accuracy: 0.3764 - val_loss: 1.3564 - val_accuracy: 0.5177
# Epoch 2/10
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.3555 - accuracy: 0.5185 - val_loss: 1.1605 - val_accuracy: 0.5843
# Epoch 3/10
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.2190 - accuracy: 0.5686 - val_loss: 1.0847 - val_accuracy: 0.6219
# Epoch 4/10
# 1563/1563 [==============================] - 18s 11ms/step - loss: 1.1278 - accuracy: 0.6056 - val_loss: 1.0124 - val_accuracy: 0.6381
# Epoch 5/10
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.0624 - accuracy: 0.6310 - val_loss: 0.9720 - val_accuracy: 0.6598
# Epoch 6/10
# 1563/1563 [==============================] - 17s 11ms/step - loss: 1.0108 - accuracy: 0.6525 - val_loss: 0.9638 - val_accuracy: 0.6717
# Epoch 7/10
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9556 - accuracy: 0.6690 - val_loss: 0.9150 - val_accuracy: 0.6826
# Epoch 8/10
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.9168 - accuracy: 0.6823 - val_loss: 0.9039 - val_accuracy: 0.6891
# Epoch 9/10
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8831 - accuracy: 0.6937 - val_loss: 0.8571 - val_accuracy: 0.7061
# Epoch 10/10
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.8551 - accuracy: 0.7041 - val_loss: 0.8477 - val_accuracy: 0.7095
# 2024-05-07 13:39:12.617975: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 122880000 exceeds 10% of free system memory.
# 313/313 - 1s - loss: 0.8477 - accuracy: 0.7095 - 673ms/epoch - 2ms/step
# Test accuracy with relu activation function: 0.7095000147819519
# Training model with activation function: sigmoid
# 2024-05-07 13:39:14.364697: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 614400000 exceeds 10% of free system memory.
# Epoch 1/10
# 1559/1563 [============================>.] - ETA: 0s - loss: 2.3060 - accuracy: 0.0984
# 2024-05-07 13:39:33.736875: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 122880000 exceeds 10% of free system memory.
# 1563/1563 [==============================] - 20s 12ms/step - loss: 2.3060 - accuracy: 0.0985 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/10
# 1563/1563 [==============================] - 18s 12ms/step - loss: 2.3035 - accuracy: 0.0991 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 3/10
# 1563/1563 [==============================] - 18s 12ms/step - loss: 2.3030 - accuracy: 0.0989 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 4/10
# 1563/1563 [==============================] - 18s 12ms/step - loss: 2.3030 - accuracy: 0.0998 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 5/10
# 1563/1563 [==============================] - 19s 12ms/step - loss: 2.3030 - accuracy: 0.0987 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 6/10
# 1563/1563 [==============================] - 19s 12ms/step - loss: 2.3031 - accuracy: 0.0983 - val_loss: 2.3028 - val_accuracy: 0.1000
# Epoch 7/10
# 1563/1563 [==============================] - 19s 12ms/step - loss: 2.0533 - accuracy: 0.2267 - val_loss: 1.7765 - val_accuracy: 0.3464
# Epoch 8/10
# 1563/1563 [==============================] - 18s 12ms/step - loss: 1.7645 - accuracy: 0.3577 - val_loss: 1.6210 - val_accuracy: 0.4230
# Epoch 9/10
# 1563/1563 [==============================] - 18s 12ms/step - loss: 1.6584 - accuracy: 0.4028 - val_loss: 1.5752 - val_accuracy: 0.4376
# Epoch 10/10
# 1563/1563 [==============================] - 18s 12ms/step - loss: 1.5930 - accuracy: 0.4256 - val_loss: 1.4914 - val_accuracy: 0.4614
# 313/313 - 1s - loss: 1.4914 - accuracy: 0.4614 - 700ms/epoch - 2ms/step
# Test accuracy with sigmoid activation function: 0.46140000224113464
# Training model with activation function: tanh
# Epoch 1/10
# 1563/1563 [==============================] - 22s 14ms/step - loss: 1.5461 - accuracy: 0.4503 - val_loss: 1.2433 - val_accuracy: 0.5687
# Epoch 2/10
# 1563/1563 [==============================] - 20s 13ms/step - loss: 1.2875 - accuracy: 0.5528 - val_loss: 1.1221 - val_accuracy: 0.6065
# Epoch 3/10
# 1563/1563 [==============================] - 20s 13ms/step - loss: 1.2008 - accuracy: 0.5860 - val_loss: 1.0960 - val_accuracy: 0.6205
# Epoch 4/10
# 1563/1563 [==============================] - 20s 13ms/step - loss: 1.1487 - accuracy: 0.6051 - val_loss: 1.0774 - val_accuracy: 0.6293
# Epoch 5/10
# 1563/1563 [==============================] - 20s 13ms/step - loss: 1.1080 - accuracy: 0.6193 - val_loss: 1.0365 - val_accuracy: 0.6422
# Epoch 6/10
# 1563/1563 [==============================] - 21s 13ms/step - loss: 1.0736 - accuracy: 0.6331 - val_loss: 1.0127 - val_accuracy: 0.6545
# Epoch 7/10
# 1563/1563 [==============================] - 20s 13ms/step - loss: 1.0488 - accuracy: 0.6379 - val_loss: 1.0349 - val_accuracy: 0.6460
# Epoch 8/10
# 1563/1563 [==============================] - 20s 13ms/step - loss: 1.0186 - accuracy: 0.6495 - val_loss: 0.9806 - val_accuracy: 0.6656
# Epoch 9/10
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.9978 - accuracy: 0.6604 - val_loss: 1.0410 - val_accuracy: 0.6388
# Epoch 10/10
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.9781 - accuracy: 0.6661 - val_loss: 1.0150 - val_accuracy: 0.6540
# 313/313 - 1s - loss: 1.0150 - accuracy: 0.6540 - 699ms/epoch - 2ms/step
# Test accuracy with tanh activation function: 0.6539999842643738
